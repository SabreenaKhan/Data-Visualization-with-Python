# %%
import matplotlib.pyplot as plt

# Meaningful data (example: Sleep hours vs. Academic Performance)
sleep_hours = [6, 7, 8, 9, 10, 8, 7.5, 9, 6.5, 8.5]
academic_performance = [75, 80, 90, 85, 95, 88, 82, 92, 78, 89]

# Create the scatter plot
plt.figure(figsize=(8, 6))  # Set the figure size
plt.scatter(sleep_hours, academic_performance, color='blue', marker='*', edgecolors='black')

# Plot the trend line
# plt.plot(sleep_hours, academic_performance, color='red', label='Trend Line')

# Label the axes
plt.xlabel("Average Sleep Hours")
plt.ylabel("Academic Performance")

#Add legend
plt.legend()

# Add a title
plt.title("Relationship Between Sleep Hours and Academic Performance (Sample Data)")

# Display the plot
plt.grid(False)  # Add gridlines for better readability
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

# Meaningful data (example: Employee ages)
employee_ages = [24, 28, 32, 27, 30, 22, 35, 40, 26, 29]

# Define the number of bins (adjust as needed)
bins = [20, 25, 30, 35, 40, 45]

# Create the histogram
plt.hist(employee_ages, bins, edgecolor='black')

# Label the axes
plt.xlabel("Age Range (Years)")
plt.ylabel("Number of Employees")

# Add a title
plt.title("Distribution of Employee Ages (Sample Data)")

# Display the plot
plt.show()

# %% [markdown]
# # Coding Challange: Data Visualisation Using Python

# %% [markdown]
# Data:
#
# The dataset contains information about different books, including:
#
# * **Title: Book title (string)**
# * **Year: Year of publication (integer)**
# * **Genre: Book genre (string)**
# * **Pages: Number of pages (integer)**
#
#
# ## Task:
#
# 1. **Import Libraries** : Begin by importing necessary libraries like `pandas` for data manipulation and `matplotlib.pyplot` for creating visualizations.
#
# 2. **Load Data** : Assume the data is stored in a CSV file named "books.csv". Use pandas.read_csv to load the data into a DataFrame.
#
# 3. **Line plot**: Create a line plot to visualize the average number of pages published each year.
# * X-axis: Year
# * Y-axis: Average number of pages
#
# 4. **Bar graph**: Create a bar graph to show the distribution of books by genre.
# * X-axis: Genre
# * Y-axis: Number of books in each genre (count)
#
# 5. **Histogram**: Create a histogram to analyze the distribution of the number of pages across all books.
# * X-axis: Number of pages (bins)
# * Y-axis: Frequency of books within each bin
#
# 6. **Scatter plot**: Create a scatter plot to explore the relationship between the year of publication and the number of pages.
# * X-axis: Year
# * Y-axis: Number of pages
#
#
#
#
# **BONUS**
# Add labels, titles, and legends to your plots for better clarity.
# Experiment with different customization options offered by matplotlib to enhance the visual appeal of your plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Import libraries (replace ... with actual import statements)

# 2. Load data (replace 'path/to/books.csv' with the actual file path)
data = pd.read_csv("path/to/books.csv")

# 3. Line plot
# ... (calculate average pages per year and plot using plt)

# 4. Bar graph
# ... (group data by genre and plot counts using plt.bar)

# 5. Histogram
# ... (use plt.hist to create the histogram with appropriate binning)

# 6. Scatter plot
# ... (plot year vs. number of pages using plt.scatter)

# ... (Add labels, titles, and legends)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
books=pd.read_csv(r"C:\Users\Sabreena Khan\Documents\Sabreena Khan\DV Challange Data - give me meaning ful data for this i means rows Ti....csv")
books
# Out:
#                                                 Title    Year  \
# 0                                                 NaN     NaN
# 1   The Lord of the Rings: The Fellowship of the Ring  1954.0
# 2                                                 NaN     NaN
# 3                                 Pride and Prejudice  1813.0
# 4                                                 NaN     NaN
# 5                The Hitchhiker's Guide to the Galaxy  1979.0
# 6                                                 NaN     NaN
# 7                                           Moby Dick  1851.0
# 8                                                 NaN     NaN
# 9                                    The Great Gatsby  1925.0
# 10                                                NaN     NaN
# 11                              To Kill a Mockingbird  1960.0
# 12                                                NaN     NaN
# 13              Harry Potter and the Sorcerer's Stone  1997.0
# ...

# %%
plt.plot(Year,Pages,color="Blue")
plt.title("Average no.of pages published each year")
plt.xlabel("Year")
plt.ylabel("Average Pages")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot(Year,Pages,color="Blue")
#       2 plt.title("Average no.of pages published each year")
#       3 plt.xlabel("Year")
#
# NameError: name 'Year' is not defined
